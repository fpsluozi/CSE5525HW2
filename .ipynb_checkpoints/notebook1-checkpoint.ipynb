# %%
# CSE5525 NLP Homework 2 Group 1
import nltk
import numpy
import itertools
from nltk.corpus import treebank

full_training_set = nltk.corpus.treebank.tagged_sents()[0:3500]
training_set1 = full_training_set[0:1750]
training_set2 = full_training_set[1750:]
test_set = nltk.corpus.treebank.tagged_sents()[3500:]

# Step 2: Retrieve P(W_i | T_i) and P(T_i| T_i-1)
#
# Sample Usage 1: 
#	print set1_cpd_tags['DT'].prob('JJ')
# 	meaning print the prob of adjective given determinor from training set 1
#
# Sample Usage 2: 
#	print full_cpd_word_tag['DT'].prob('the')
# 	meaning print the prob of word 'the' given determinor from full training set
#
# PS. cpd as the Conditional Prob Distribution
# PSS. We use Laplace distribution for unseen cases

# Full Traning Set
full_training_set_words = []
for sent in full_training_set:
	full_training_set_words.append(('S','S'))
	full_training_set_words.extend([ (tag, word) for (word, tag) in sent ])
	full_training_set_words.append(('T','T'))

full_cfd_word_tag = nltk.ConditionalFreqDist(full_training_set_words)
full_cpd_word_tag = nltk.ConditionalProbDist(full_cfd_word_tag, nltk.SimpleGoodTuringProbDist)

full_tags = [tag for (tag, word) in full_training_set_words]
full_cfd_tags = nltk.ConditionalFreqDist(nltk.bigrams(full_tags))
full_cpd_tags = nltk.ConditionalProbDist(full_cfd_tags, nltk.SimpleGoodTuringProbDist)

# Traning Set 1
set1_training_set_words = []
for sent in training_set1:
	set1_training_set_words.append(('S','S'))
	set1_training_set_words.extend([ (tag, word) for (word, tag) in sent ])
	set1_training_set_words.append(('T','T'))

set1_cfd_word_tag = nltk.ConditionalFreqDist(set1_training_set_words)
set1_cpd_word_tag = nltk.ConditionalProbDist(set1_cfd_word_tag, nltk.SimpleGoodTuringProbDist)

set1_tags = [tag for (tag, word) in set1_training_set_words]
set1_cfd_tags = nltk.ConditionalFreqDist(nltk.bigrams(set1_tags)) # notice the training set still utilizes the full tag set
set1_cpd_tags = nltk.ConditionalProbDist(set1_cfd_tags, nltk.SimpleGoodTuringProbDist)

# %%
import numpy

# %%
set1_cpd_tags['PRP$'].prob('#')
# Out:
# 0.016483516483516484

# %%
nltk.corpus.treebank.tagset()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-76068af1233d> in <module>()
# ----> 1 nltk.corpus.treebank.tagset()
#
# AttributeError: 'BracketParseCorpusReader' object has no attribute 'tagset'

# %%
set1_tags
# Out:
# ['S',
#  u'NNP',
#  u'NNP',
#  u',',
#  u'CD',
#  u'NNS',
#  u'JJ',
#  u',',
#  u'MD',
#  u'VB',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'JJ',
#  u'NN',
#  u'NNP',
#  u'CD',
#  u'.',
#  'T',
#  'S',
#  u'NNP',
#  u'NNP',
#  u'VBZ',
#  u'NN',
#  u'IN',
#  u'NNP',
#  u'NNP',
#  u',',
#  u'DT',
#  u'NNP',
#  u'VBG',
#  u'NN',
#  u'.',
#  'T',
#  'S',
#  u'NNP',
#  u'NNP',
#  u',',
#  u'CD',
#  u'NNS',
#  u'JJ',
#  u'CC',
#  u'JJ',
#  u'NN',
#  u'IN',
#  u'NNP',
#  u'NNP',
#  u'NNP',
#  u'NNP',
#  u',',
#  u'VBD',
#  u'VBN',
#  u'-NONE-',
#  u'DT',
#  u'JJ',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'JJ',
#  u'JJ',
#  u'NN',
#  u'.',
#  'T',
#  'S',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'NN',
#  u'RB',
#  u'VBN',
#  u'-NONE-',
#  u'-NONE-',
#  u'TO',
#  u'VB',
#  u'NNP',
#  u'NN',
#  u'NNS',
#  u'VBZ',
#  u'VBN',
#  u'DT',
#  u'JJ',
#  u'NN',
#  u'IN',
#  u'NN',
#  u'NNS',
#  u'IN',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'NNS',
#  u'VBN',
#  u'-NONE-',
#  u'TO',
#  u'PRP',
#  u'RBR',
#  u'IN',
#  u'CD',
#  u'NNS',
#  u'IN',
#  u',',
#  u'NNS',
#  u'VBD',
#  u'-NONE-',
#  u'-NONE-',
#  u'.',
#  'T',
#  'S',
#  u'DT',
#  u'NN',
#  u'NN',
#  u',',
#  u'NN',
#  u',',
#  u'VBZ',
#  u'RB',
#  u'JJ',
#  u'IN',
#  u'PRP',
#  u'VBZ',
#  u'DT',
#  u'NNS',
#  u',',
#  u'IN',
#  u'RB',
#  u'JJ',
#  u'NNS',
#  u'TO',
#  u'PRP',
#  u'VBG',
#  u'NNS',
#  u'WDT',
#  u'-NONE-',
#  u'VBP',
#  u'RP',
#  u'NNS',
#  u'JJ',
#  u',',
#  u'NNS',
#  u'VBD',
#  u'-NONE-',
#  u'-NONE-',
#  u'.',
#  'T',
#  'S',
#  u'NNP',
#  u'NNP',
#  u',',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'JJ',
#  u'JJ',
#  u'NNP',
#  u'NNP',
#  u'WDT',
#  u'-NONE-',
#  u'VBZ',
#  u'NNP',
#  u'NNS',
#  u',',
#  u'VBD',
#  u'VBG',
#  u'NN',
#  u'IN',
#  u'PRP$',
#  u'NN',
#  u'NN',
#  u'NNS',
#  u'IN',
#  u'CD',
#  u'.',
#  'T',
#  'S',
#  u'IN',
#  u'JJ',
#  u'NNS',
#  u'VBD',
#  u'VBN',
#  u'-NONE-',
#  u'RBR',
#  u'IN',
#  u'DT',
#  u'NN',
#  u'IN',
#  u',',
#  u'DT',
#  u'JJS',
#  u'NNS',
#  u'VBP',
#  u'IN',
#  u'NN',
#  u'POS',
#  u'NNP',
#  u'NNP',
#  u'NNP',
#  u'IN',
#  u'NNP',
#  u',',
#  u'DT',
#  u'NN',
#  u'JJ',
#  u'-NONE-',
#  u'TO',
#  u'VB',
#  u'JJ',
#  u'NN',
#  u'TO',
#  u'DT',
#  u'NN',
#  u'.',
#  'T',
#  'S',
#  u'DT',
#  u'NNP',
#  u'NN',
#  u'VBD',
#  u',',
#  u'``',
#  u'DT',
#  u'VBZ',
#  u'DT',
#  u'JJ',
#  u'NN',
#  u'.',
#  'T',
#  'S',
#  u'PRP',
#  u'VBP',
#  u'VBG',
#  u'IN',
#  u'NNS',
#  u'IN',
#  u'IN',
#  u'NN',
#  u'VBD',
#  u'IN',
#  u'NN',
#  u'VBG',
#  u'DT',
#  u'JJ',
#  u'NNS',
#  u'.',
#  'T',
#  'S',
#  u'EX',
#  u'VBZ',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'PRP$',
#  u'NNS',
#  u'RB',
#  u'.',
#  u"''",
#  'T',
#  'S',
#  u'DT',
#  u'NNP',
#  u'CC',
#  u'DT',
#  u'NNS',
#  u'WP',
#  u'-NONE-',
#  u'VBD',
#  u'DT',
#  u'NNS',
#  u'VBD',
#  u'JJ',
#  u'IN',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'NNS',
#  u'IN',
#  u'DT',
#  u'NNP',
#  u'NNS',
#  u'.',
#  'T',
#  'S',
#  u'``',
#  u'PRP',
#  u'VBP',
#  u'DT',
#  u'JJ',
#  u'NN',
#  u'IN',
#  u'IN',
#  u'NNS',
#  u'VBP',
#  u'IN',
#  u'NN',
#  u',',
#  u"''",
#  u'VBD',
#  u'-NONE-',
#  u'NNP',
#  u'NNP',
#  u'NNP',
#  u'IN',
#  u'NNP',
#  u'POS',
#  u'NNP',
#  u'NNP',
#  u'NNP',
#  u'.',
#  'T',
#  'S',
#  u'NNP',
#  u'NNP',
#  u'VBD',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'NNS',
#  u'IN',
#  u'DT',
#  u'NNP',
#  u'NNP',
#  u'NNP',
#  u'CC',
#  u'DT',
#  u'JJ',
#  u'NNS',
#  u'IN',
#  u'NNP',
#  u'NNP',
#  u'CC',
#  u'NNP',
#  u'NNP',
#  u'.',
#  'T',
#  'S',
#  u'DT',
#  u'NNP',
#  u'NN',
#  u'VBD',
#  u'-NONE-',
#  u'NN',
#  u'VBD',
#  u'VBN',
#  u'-NONE-',
#  u'IN',
#  u'``',
#  u'RB',
#  u'JJ',
#  u'NNS',
#  u"''",
#  u'IN',
#  u'-NONE-',
#  u'VBG',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'NNS',
#  u'IN',
#  u'DT',
#  u'JJ',
#  u'CD',
#  u'CC',
#  u'VBN',
#  u'-NONE-',
#  u'IN',
#  u'DT',
#  u'JJ',
#  u'NN',
#  u'IN',
#  u'NN',
#  u'IN',
#  u'CD',
#  u'.',
#  'T',
#  'S',
#  u'IN',
#  u'CD',
#  u'TO',
#  u'CD',
#  u',',
#  u'CD',
#  u'CD',
#  u'NNP',
#  u'NNS',
#  u'IN',
#  u'DT',
#  u'NNS',
#  u'VBD',
#  u'VBN',
#  u'-NONE-',
#  u',',
#  u'DT',
#  u'NN',
#  u'VBD',
#  u'-NONE-',
#  u'-NONE-',
#  u'.',
#  'T',
#  'S',
#  u'IN',
#  u'CD',
#  u'NNS',
#  u'WP',
#  u'-NONE-',
#  u'VBD',
#  u'RB',
#  u'IN',
#  u'DT',
#  u'NN',
#  u',',
#  u'CD',
#  u'-NONE-',
#  u'VBP',
#  u'VBN',
#  u':',
#  u'JJ',
#  u'IN',
#  u'CD',
#  u'NNS',
#  u'DT',
#  u'VBN',
#  u'NN',
#  u'.',
#  'T',
#  'S',
#  u'CD',
#  u'IN',
#  u'DT',
#  u'CD',
#  u'VBG',
#  u'NNS',
#  u'VBP',
#  u'JJ',
#  u'NNS',
#  u',',
#  u'VBG',
#  u'CD',
#  u'IN',
#  u'RB',
#  u'VBN',
#  u'NN',
#  u'.',
#  'T',
#  'S',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'CD',
#  u'NNS',
#  u'IN',
#  u'JJ',
#  u'NN',
#  u',',
#  u'NN',
#  u'NN',
#  u'CC',
#  u'NN',
#  u'VBD',
#  u'RB',
#  u'JJR',
#  u'IN',
#  u'-NONE-',
#  u'VBN',
#  u'-NONE-',
#  u',',
#  u'DT',
#  u'NNS',
#  u'VBD',
#  u'-NONE-',
#  u'-NONE-',
#  u'.',
#  'T',
#  'S',
#  u'``',
#  u'DT',
#  u'NN',
#  u'NN',
#  u'VBZ',
#  u'DT',
#  u'JJ',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'IN',
#  u'PRP',
#  u'WP',
#  u'-NONE-',
#  u'VBP',
#  u'JJ',
#  u'NNS',
#  u',',
#  u"''",
#  u'VBD',
#  u'-NONE-',
#  u'NNP',
#  u'NNP',
#  u'.',
#  'T',
#  'S',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'NN',
#  u'NN',
#  u'NNS',
#  u'IN',
#  u'DT',
#  u'NNS',
#  u'IN',
#  u'DT',
#  u'NNP',
#  u'NNP',
#  u',',
#  u'NNP',
#  u',',
#  u'NN',
#  u'NN',
#  u'VBZ',
#  u'-NONE-',
#  u'TO',
#  u'VB',
#  u'DT',
#  u'JJS',
#  u'IN',
#  u'DT',
#  u'NN',
#  u'NNS',
#  u'VBN',
#  u'-NONE-',
#  u'IN',
#  u'JJ',
#  u'VBN',
#  u'NNS',
#  u',',
#  u'PRP',
#  u'VBD',
#  u'-NONE-',
#  u'-NONE-',
#  u'.',
#  'T',
#  'S',
#  u'DT',
#  u'NN',
#  u',',
#  u'WDT',
#  u'-NONE-',
#  u'VBZ',
#  u'VBN',
#  u'-NONE-',
#  u'IN',
#  u'NNP',
#  u'CC',
#  u'NNP',
#  u'NNP',
#  u',',
#  u'VBD',
#  u'IN',
#  u'NN',
#  u'-NONE-',
#  u'IN',
#  u'NN',
#  u'-NONE-',
#  u'TO',
#  u'VB',
#  u'DT',
#  u'NN',
#  u'NNS',
#  u'.',
#  'T',
#  'S',
#  u'DT',
#  u'NN',
#  u'RB',
#  u'MD',
#  u'VB',
#  u'DT',
#  u'WP',
#  u'-NONE-',
#  u'VBP',
#  u'IN',
#  u'DT',
#  u'NNP',
#  u'MD',
#  u'VB',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'NN',
#  u'VBG',
#  u'NN',
#  u'RBR',
#  u'RB',
#  u'IN',
#  u'DT',
#  u'JJ',
#  u'NN',
#  u'IN',
#  u'NN',
#  u',',
#  u'NN',
#  u',',
#  u'VBN',
#  u'-NONE-',
#  u'IN',
#  u'JJS',
#  u'NNS',
#  u'CC',
#  u'JJ',
#  u'NNS',
#  u',',
#  u'NNP',
#  u'NNP',
#  u'VBD',
#  u'-NONE-',
#  u'-NONE-',
#  u'.',
#  'T',
#  'S',
#  u'DT',
#  u'NNP',
#  u'VBZ',
#  u'CD',
#  u'IN',
#  u'DT',
#  u'JJ',
#  u'VBN',
#  u'NNS',
#  u'WDT',
#  u'-NONE-',
#  u'VBZ',
#  u'RB',
#  u'VB',
#  u'DT',
#  u'JJR',
#  u'NN',
#  u'IN',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'JJ',
#  u',',
#  u'JJ',
#  u'NNS',
#  u'JJ',
#  u'IN',
#  u'NN',
#  u'WDT',
#  u'-NONE-',
#  u'VBP',
#  u'VBN',
#  u'-NONE-',
#  u'IN',
#  u'NNS',
#  u',',
#  u'VBG',
#  u'TO',
#  u'NNP',
#  u'NNP',
#  u'NNP',
#  u',',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'NNP',
#  u'IN',
#  u'NNP',
#  u'NNP',
#  u'IN',
#  u'NNP',
#  u'.',
#  'T',
#  'S',
#  u'RBR',
#  u'JJ',
#  u'NN',
#  u'NNS',
#  u'VBP',
#  u'JJ',
#  u'CC',
#  u'VBP',
#  u'RBR',
#  u'RB',
#  u'VBN',
#  u'-NONE-',
#  u'IN',
#  u'DT',
#  u'NN',
#  u',',
#  u'NNP',
#  u'NNP',
#  u'VBD',
#  u'-NONE-',
#  u'-NONE-',
#  u'.',
#  'T',
#  'S',
#  u'IN',
#  u'NNP',
#  u',',
#  u'DT',
#  u'NNP',
#  u'NNP',
#  u'NNP',
#  u'VBD',
#  u'DT',
#  u'JJ',
#  u'NN',
#  u'IN',
#  u'RB',
#  u'DT',
#  u'NNS',
#  u'IN',
#  u'NN',
#  u'.',
#  'T',
#  'S',
#  u'IN',
#  u'CD',
#  u',',
#  u'RB',
#  u'DT',
#  u'VBG',
#  u'NNS',
#  u'IN',
#  u'JJ',
#  u'NN',
#  u'MD',
#  u'VB',
#  u'VBN',
#  u'-NONE-',
#  u'.',
#  'T',
#  'S',
#  u'IN',
#  u'CD',
#  u'NNS',
#  u'IN',
#  u'DT',
#  u'NN',
#  u'WDT',
#  u'-NONE-',
#  u'VBD',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'NNP',
#  u'NNS',
#  u'VBD',
#  u'VBN',
#  u'-NONE-',
#  u'TO',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'CD',
#  u'.',
#  'T',
#  'S',
#  u'NNS',
#  u'IN',
#  u'DT',
#  u'NN',
#  u'-NONE-',
#  u'VBD',
#  u'RB',
#  u'JJ',
#  u'WRB',
#  u'DT',
#  u'NN',
#  u'VBD',
#  u'VBN',
#  u'-NONE-',
#  u'-NONE-',
#  u'.',
#  'T',
#  'S',
#  u'NNS',
#  u'VBD',
#  u'JJ',
#  u'NN',
#  u'NNS',
#  u'IN',
#  u'DT',
#  u'VBN',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'JJ',
#  u'NN',
#  u',',
#  u'VBD',
#  u'RP',
#  u'NN',
#  u'CC',
#  u'NN',
#  u'NNS',
#  u'CC',
#  u'RB',
#  u'VBD',
#  u'DT',
#  u'JJ',
#  u'NNS',
#  u'IN',
#  u'DT',
#  u'NN',
#  u'VBN',
#  u'-NONE-',
#  u'-NONE-',
#  u'TO',
#  u'VB',
#  u'NNS',
#  u'.',
#  'T',
#  'S',
#  u'NNS',
#  u'VBD',
#  u'``',
#  u'NNS',
#  u'IN',
#  u'JJ',
#  u'NN',
#  u"''",
#  u'WDT',
#  u'-NONE-',
#  u'VBD',
#  u'IN',
#  u'NNS',
#  u'IN',
#  u'DT',
#  u'NN',
#  u',',
#  u'RB',
#  u'IN',
#  u'NN',
#  u'NNS',
#  u'VBD',
#  u'DT',
#  u'NN',
#  u'.',
#  'T',
#  'S',
#  u'``',
#  u'EX',
#  u'VBZ',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'IN',
#  u'DT',
#  u'NNS',
#  u'CC',
#  u'NNS',
#  u'VBD',
#  u'JJ',
#  u'NNS',
#  u',',
#  u"''",
#  u'VBD',
#  u'-NONE-',
#  u'NNP',
#  u'NNP',
#  u',',
#  u'NN',
#  u'NN',
#  u'IN',
#  u'JJ',
#  u'NNS',
#  u'IN',
#  u'NNP',
#  u'CC',
#  u'NNP',
#  u'.',
#  'T',
#  'S',
#  u'``',
#  u'CC',
#  u'PRP',
#  u'VBP',
#  u'-NONE-',
#  u'TO',
#  u'VB',
#  u'IN',
#  u'DT',
#  u'NNS',
#  u'VBD',
#  u'NN',
#  u'CD',
#  u'NNS',
#  u'IN',
#  u'.',
#  'T',
#  'S',
#  u'PRP',
#  u'VBZ',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'PRP$',
#  u'NN',
#  u'NN',
#  u'NN',
#  u'.',
#  'T',
#  'S',
#  u'NNS',
#  u'IN',
#  u'JJ',
#  u'JJ',
#  u'NNS',
#  u'VBD',
#  u'-NONE-',
#  u'TO',
#  u'VB',
#  u',',
#  u'IN',
#  u'NNS',
#  u'IN',
#  u'NN',
#  u'NNS',
#  u'VBP',
#  u'JJ',
#  u'NNS',
#  u'IN',
#  u'NN',
#  u'NNS',
#  u'.',
#  'T',
#  'S',
#  u'DT',
#  u'JJ',
#  u'JJ',
#  u'NN',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'CD',
#  u'JJ',
#  u'NNS',
#  u'VBN',
#  u'-NONE-',
#  u'IN',
#  u'NNP',
#  u'POS',
#  u'NNP',
#  u'NNP',
#  u'NNP',
#  u'VBD',
#  u'DT',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'NN',
#  u'NN',
#  u'TO',
#  u'CD',
#  u'NN',
#  u'IN',
#  u'CD',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'NN',
#  u'VBD',
#  u'NNP',
#  u'.',
#  'T',
#  'S',
#  u'NN',
#  u'NNS',
#  u'VBP',
#  u'NN',
#  u'IN',
#  u'NNS',
#  u'CC',
#  u'IN',
#  u'DT',
#  u'JJ',
#  u'NN',
#  u'VBZ',
#  u'IN',
#  u'DT',
#  u'NN',
#  u'.',
#  'T',
#  'S',
#  u'JJ',
#  u'NN',
#  u'IN',
#  u'DT',
#  u'NNS',
#  u'POS',
#  u'NNS',
#  u'VBD',
#  u'IN',
#  u'DT',
#  u'NN',
#  u'TO',
#  ...]
